# %%
import sys
import pyaudio
import wave
import audioop
import time
#To edit range so they are all three digit values
from numpy import interp


import serial

# %%
def getAmbientAudio():
    CHUNK = 1024 
    FORMAT = pyaudio.paInt16 #paInt8
    CHANNELS = 2 
    RATE = 44100 #sample rate
    RECORD_SECONDS = 15

    p = pyaudio.PyAudio()

    stream = p.open(format=FORMAT,
                    channels=CHANNELS,
                    rate=RATE,
                    input=True,
                    frames_per_buffer=CHUNK) #buffer
    frames = []

    total = int(RATE / CHUNK * RECORD_SECONDS)
    print total
    total_rms = 0;
    for i in range(0, total):
        data = stream.read(CHUNK)
        frames.append(data) # 2 bytes(16 bits) per channel
        #rms gets the actual volume, since the data has lots of other info   
        rms = audioop.rms(data,2)
        total_rms += rms
        #rms_one = int(interp(rms, [1,4000],[1,1000]))
        #maybe I want to write a "head and tail character" so that I know when it ends
        # print rms
    avg_rms = total_rms/float(total)
    print "avg rms = " + str(avg_rms)
    return avg_rms
        
    stream.stop_stream()
    stream.close()

    # close PyAudio (5)
    p.terminate()

# %%
def checkaudio(level, baseline):
    CHUNK = 1024 
    FORMAT = pyaudio.paInt16 #paInt8
    CHANNELS = 2 
    RATE = 44100 #sample rate
    RECORD_SECONDS = 10

    p = pyaudio.PyAudio()

    stream = p.open(format=FORMAT,
                    channels=CHANNELS,
                    rate=RATE,
                    input=True,
                    frames_per_buffer=CHUNK) #buffer

    frames = []

    for i in range(0, int(RATE / CHUNK * RECORD_SECONDS)):
        data = stream.read(CHUNK)
        frames.append(data) # 2 bytes(16 bits) per channel
        #rms gets the actual volume, since the data has lots of other info   
        rms = audioop.rms(data,2)
        print rms
        if level == 1 and rms > baseline*10:
            # active
            print "ACTIVE. SCREAMED. DONE."
            stream.stop_stream()
            stream.close()
            p.terminate()

            arduino.write('done')
            break
        if level == 2 and rms > baseline*5:
            # quiet
            print "ACTIVE. SCREAMED. DONE."
            stream.stop_stream()
            stream.close()
            p.terminate()

            arduino.write('done')
            break


    stream.stop_stream()
    stream.close()

    # close PyAudio (5)
    p.terminate()

    arduino.write('x')

# %%
ambientLevel =getAmbientAudio()
# Out:
# 645
# avg rms = 2610.91472868

# %%
ambientLevel=800

# %%
val = 0
full_val = ''
#From  http://www.olgapanades.com/blog/controlling-arduino-with-python/
arduino = serial.Serial('/dev/tty.usbmodemfa141', 9600)
while 1:
    #Reset variables
    val = 0
    full_val = ''
    #Pull the line
    if arduino.inWaiting():
        try:
            val = arduino.readline(arduino.inWaiting())
            print "val = " + val

            for char in val:
                #Make sure that the character isn't some weird thing
                if char.isalpha():
                    full_val = full_val + char
            print "Cleaned value is: " + full_val
            if full_val == 'activecomplete':
                print 'received activecomplete, now listening...'
                checkaudio(1, ambientLevel)
                break
            elif full_val == 'quietcomplete':
                print 'received quietcomplete, now listening...'
                checkaudio(2, ambientLevel)
                break
        except serial.serialutil.SerialException:
            pass
# Out:
# val =
# Cleaned value is:
# val = ctiv
# Cleaned value is: ctiv
# val = ecom
# Cleaned value is: ecom
# val = plet
# Cleaned value is: plet
# val = e
#
# Cleaned value is: e
# val = a
# Cleaned value is: a
# val = ctve
# Cleaned value is: ctve
# val = com
# Cleaned value is: com
# val = plet
# Cleaned value is: plet
# val = e
#
# Cleaned value is: e
# val = a
# Cleaned value is: a
# val = ctiv
# Cleaned value is: ctiv
# val = ple
# Cleaned value is: ple
# val = te
#
# Cleaned value is: te
# val = acti
# Cleaned value is: acti
# val = veco
# Cleaned value is: veco
# val = plet
# Cleaned value is: plet
# val = e
#
# Cleaned value is: e
# val = acti
# Cleaned value is: acti
# val = veco
# Cleaned value is: veco
# val = mple
# Cleaned value is: mple
# val = t
#
# Cleaned value is: t
# val = acti
# Cleaned value is: acti
# val = veco
# Cleaned value is: veco
# val = mple
# Cleaned value is: mple
# val = te
#
# Cleaned value is: te
# val = ativ
# Cleaned value is: ativ
# val = eco
# Cleaned value is: eco
# val = mpl
# Cleaned value is: mpl
# val = ete
# Cleaned value is: ete
# val =
#
# Cleaned value is:
# val = act
# Cleaned value is: act
# val = veom
# Cleaned value is: veom
# val = pl
# Cleaned value is: pl
# val = ete
# Cleaned value is: ete
# val =
#
# Cleaned value is:
# val = act
# Cleaned value is: act
# val = ivec
# Cleaned value is: ivec
# val = ople
# Cleaned value is: ople
# val = te
# Cleaned value is: te
# val =
#
# Cleaned value is:
# val = act
# Cleaned value is: act
# val = ivec
# Cleaned value is: ivec
# val = ompl
# Cleaned value is: ompl
# val = ee
#
# Cleaned value is: ee
# val = act
# Cleaned value is: act
# val = ive
# Cleaned value is: ive
# val = comp
# Cleaned value is: comp
# val = lete
# Cleaned value is: lete
# act
# Cleaned value is: act
# val = ive
# Cleaned value is: ive
# val = comp
# Cleaned value is: comp
# val = lete
# Cleaned value is: lete
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = tive
# Cleaned value is: tive
# val = lete
# Cleaned value is: lete
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = tive
# Cleaned value is: tive
# val = comp
# Cleaned value is: comp
# val = ete
#
# Cleaned value is: ete
# val = tiv
# Cleaned value is: tiv
# val = ecom
# Cleaned value is: ecom
# val = plet
# Cleaned value is: plet
# val = e
#
# Cleaned value is: e
# val = a
# Cleaned value is: a
# val = ctiv
# Cleaned value is: ctiv
# val = eomp
# Cleaned value is: eomp
# val = let
# Cleaned value is: let
# val = e
# Cleaned value is: e
# val = a
# Cleaned value is: a
# val = ctiv
# Cleaned value is: ctiv
# val = ecom
# Cleaned value is: ecom
# val = pete
# Cleaned value is: pete
# val =
#
# Cleaned value is:
# val = a
# Cleaned value is: a
# val = ctiv
# Cleaned value is: ctiv
# val = ecom
# Cleaned value is: ecom
# val = plet
# Cleaned value is: plet
# ac
# Cleaned value is: eac
# val = ti
# Cleaned value is: ti
# val = veco
# Cleaned value is: veco
# val = mple
# Cleaned value is: mple
# val = te
#
# Cleaned value is: te
# val = acti
# Cleaned value is: acti
# val = mple
# Cleaned value is: mple
# val = te
#
# Cleaned value is: te
# val = acti
# Cleaned value is: acti
# val = veco
# Cleaned value is: veco
# val = plet
# Cleaned value is: plet
# val = e
#
# Cleaned value is: e
# val = acti
# Cleaned value is: acti
# val = veco
# Cleaned value is: veco
# val = mple
# Cleaned value is: mple
# val = e
#
# Cleaned value is: e
# val = act
# Cleaned value is: act
# val = ivec
# Cleaned value is: ivec
# val = ompl
# Cleaned value is: ompl
# val = ete
# Cleaned value is: ete
# val = ive
# Cleaned value is: ive
# val = c
# Cleaned value is: c
# val = ompl
# Cleaned value is: ompl
# val = ete
# Cleaned value is: ete
# val =
#
# Cleaned value is:
# val = act
# Cleaned value is: act
# val = ieco
# Cleaned value is: ieco
# val = mpl
# Cleaned value is: mpl
# val = ete
# Cleaned value is: ete
# val =
#
# Cleaned value is:
# val = act
# Cleaned value is: act
# val = ivec
# Cleaned value is: ivec
# val = mle
# Cleaned value is: mle
# val = te
# Cleaned value is: te
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = tive
# Cleaned value is: tive
# val = comp
# Cleaned value is: comp
# val = lee
# Cleaned value is: lee
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = tive
# Cleaned value is: tive
# val = comp
# Cleaned value is: comp
# val = lete
# Cleaned value is: lete
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = tvec
# Cleaned value is: tvec
# val = omp
# Cleaned value is: omp
# val = lete
# Cleaned value is: lete
# val =
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = tive
# Cleaned value is: tive
# val = omp
# Cleaned value is: omp
# val = let
# Cleaned value is: let
# val = e
#
# Cleaned value is: e
# val = a
# Cleaned value is: a
# val = ctiv
# Cleaned value is: ctiv
# val = ecom
# Cleaned value is: ecom
# val = e
#
# Cleaned value is: e
# val = a
# Cleaned value is: a
# val = ctiv
# Cleaned value is: ctiv
# val = ecom
# Cleaned value is: ecom
# val = plet
# Cleaned value is: plet
# val =
#
# Cleaned value is:
# val = ctiv
# Cleaned value is: ctiv
# val = ecom
# Cleaned value is: ecom
# val = plet
# Cleaned value is: plet
# val = e
#
# Cleaned value is: e
# val = a
# Cleaned value is: a
# val = tive
# Cleaned value is: tive
# val = co
# Cleaned value is: co
# val = mple
# Cleaned value is: mple
# val = te
#
# Cleaned value is: te
# val = acti
# Cleaned value is: acti
# val = veco
# Cleaned value is: veco
# val = pee
# Cleaned value is: pee
# val = tive
# Cleaned value is: tive
# val = comp
# Cleaned value is: comp
# val = lete
# Cleaned value is: lete
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = comp
# Cleaned value is: comp
# val = lete
# Cleaned value is: lete
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = tive
# Cleaned value is: tive
# val = cmpe
# Cleaned value is: cmpe
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = tiv
# Cleaned value is: tiv
# val = ecom
# Cleaned value is: ecom
# val = plet
# Cleaned value is: plet
# val = e
#
# Cleaned value is: e
# val = ctiv
# Cleaned value is: ctiv
# val = ecom
# Cleaned value is: ecom
# val = plet
# Cleaned value is: plet
# val = e
#
# Cleaned value is: e
# val = a
# Cleaned value is: a
# val = tive
# Cleaned value is: tive
# val = com
# Cleaned value is: com
# val = plet
# Cleaned value is: plet
# val = e
#
# Cleaned value is: e
# val = a
# Cleaned value is: a
# val = ctiv
# Cleaned value is: ctiv
# val = ecmp
# Cleaned value is: ecmp
# val = let
# Cleaned value is: let
# val = e
#
# Cleaned value is: e
# val = a
# Cleaned value is: a
# val = cti
# Cleaned value is: cti
# val = veco
# Cleaned value is: veco
# val = plte
# Cleaned value is: plte
# val =
#
# Cleaned value is:
# val = acti
# Cleaned value is: acti
# val = veco
# Cleaned value is: veco
# val = mple
# Cleaned value is: mple
# val = t
#
# Cleaned value is: t
# val = acti
# Cleaned value is: acti
# val = veco
# Cleaned value is: veco
# val = mple
# Cleaned value is: mple
# val = te
# Cleaned value is: te
# val = ctiv
# Cleaned value is: ctiv
# val = eco
# Cleaned value is: eco
# val = mple
# Cleaned value is: mple
# val = te
# Cleaned value is: te
# val =
#
# Cleaned value is:
# val = act
# Cleaned value is: act
# val = ieco
# Cleaned value is: ieco
# val = mpl
# Cleaned value is: mpl
# val = ete
# Cleaned value is: ete
# val =
#
# Cleaned value is:
# val = act
# Cleaned value is: act
# val = ivec
# Cleaned value is: ivec
# val = omle
# Cleaned value is: omle
# val = te
# Cleaned value is: te
# val =
# Cleaned value is:
# val = act
# Cleaned value is: act
# val = ivec
# Cleaned value is: ivec
# val = ompl
# Cleaned value is: ompl
# val =
#
# Cleaned value is:
# val = tvec
# Cleaned value is: tvec
# val = o
# Cleaned value is: o
# val = mple
# Cleaned value is: mple
# val = te
#
# Cleaned value is: te
# val = acti
# Cleaned value is: acti
# val = vco
# Cleaned value is: vco
# val = mpl
# Cleaned value is: mpl
# val = ete
# Cleaned value is: ete
# val =
#
# Cleaned value is:
# val = act
# Cleaned value is: act
# val = ivec
# Cleaned value is: ivec
# val = mpet
# Cleaned value is: mpet
# val = e
# Cleaned value is: e
# val =
#
# Cleaned value is:
# val = act
# Cleaned value is: act
# val = ivec
# Cleaned value is: ivec
# val = ompl
# Cleaned value is: ompl
# val = te
#
# Cleaned value is: te
# val = act
# Cleaned value is: act
# val = ivec
# Cleaned value is: ivec
# val = ompl
# Cleaned value is: ompl
# val = ete
# Cleaned value is: ete
# val =
#
# Cleaned value is:
# val = tive
# Cleaned value is: tive
# val = comp
# Cleaned value is: comp
# val = lete
# Cleaned value is: lete
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = ivco
# Cleaned value is: ivco
# val = mp
# Cleaned value is: mp
# val = lete
# Cleaned value is: lete
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = tive
# Cleaned value is: tive
# val = cmle
# Cleaned value is: cmle
# val = te
# Cleaned value is: te
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = tive
# Cleaned value is: tive
# val = comp
# Cleaned value is: comp
# val = lte
# Cleaned value is: lte
# val =
#
# Cleaned value is:
# val = a
# Cleaned value is: a
# val = ctiv
# Cleaned value is: ctiv
# val = ecom
# Cleaned value is: ecom
# val = plet
# Cleaned value is: plet
# val =
# Cleaned value is:
# val = ctiv
# Cleaned value is: ctiv
# val = ecom
# Cleaned value is: ecom
# val = plet
# Cleaned value is: plet
# val = e
#
# Cleaned value is: e
# val = a
# Cleaned value is: a
# val = ctve
# Cleaned value is: ctve
# val = com
# Cleaned value is: com
# val = plet
# Cleaned value is: plet
# val = e
#
# Cleaned value is: e
# val = a
# Cleaned value is: a
# val = ctiv
# Cleaned value is: ctiv
# val = ecom
# Cleaned value is: ecom
# val = te
#
# Cleaned value is: te
# val = acti
# Cleaned value is: acti
# val = veco
# Cleaned value is: veco
# val = mple
# Cleaned value is: mple
# val = acti
# Cleaned value is: acti
# val = veco
# Cleaned value is: veco
# val = mple
# Cleaned value is: mple
# val = te
#
# Cleaned value is: te
# val = ctve
# Cleaned value is: ctve
# val = co
# Cleaned value is: co
# val = mple
# Cleaned value is: mple
# val = te
#
# Cleaned value is: te
# val = acti
# Cleaned value is: acti
# val = vecm
# Cleaned value is: vecm
# val = pl
# Cleaned value is: pl
# val = ete
# Cleaned value is: ete
# val =
#
# Cleaned value is:
# val = act
# Cleaned value is: act
# val = ivec
# Cleaned value is: ivec
# val = ople
# Cleaned value is: ople
# val = te
# Cleaned value is: te
# val =
#
# Cleaned value is:
# val = act
# Cleaned value is: act
# val = ivec
# Cleaned value is: ivec
# val = ompl
# Cleaned value is: ompl
# val = ee
#
# Cleaned value is: ee
# val = act
# Cleaned value is: act
# val = ivec
# Cleaned value is: ivec
# val = ompl
# Cleaned value is: ompl
# val = ete
# Cleaned value is: ete
# val =
# Cleaned value is:
# val = ive
# Cleaned value is: ive
# val = comp
# Cleaned value is: comp
# val = lete
# Cleaned value is: lete
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = tveo
# Cleaned value is: tveo
# val = lete
# Cleaned value is: lete
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = tive
# Cleaned value is: tive
# val = comp
# Cleaned value is: comp
# val = ete
# Cleaned value is: ete
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = tive
# Cleaned value is: tive
# val = comp
# Cleaned value is: comp
# val = lete
# Cleaned value is: lete
# val =
#
# Cleaned value is:
# val = tiv
# Cleaned value is: tiv
# val = ecom
# Cleaned value is: ecom
# val = plet
# Cleaned value is: plet
# val = e
#
# Cleaned value is: e
# val = a
# Cleaned value is: a
# val = cive
# Cleaned value is: cive
# val = com
# Cleaned value is: com
# val = plet
# Cleaned value is: plet
# val = e
#
# Cleaned value is: e
# val = a
# Cleaned value is: a
# val = ctiv
# Cleaned value is: ctiv
# val = comp
# Cleaned value is: comp
# val = let
# Cleaned value is: let
# val = e
#
# Cleaned value is: e
# val = a
# Cleaned value is: a
# val = ctiv
# Cleaned value is: ctiv
# val = ecom
# Cleaned value is: ecom
# val = plte
# Cleaned value is: plte
# val =
#
# Cleaned value is:
# val = acti
# Cleaned value is: acti
# val = veco
# Cleaned value is: veco
# val = mple
# Cleaned value is: mple
# val = e
#
# Cleaned value is: e
# val = acti
# Cleaned value is: acti
# val = veco
# Cleaned value is: veco
# val = mple
# Cleaned value is: mple
# val = te
#
# Cleaned value is: te
# val = ctve
# Cleaned value is: ctve
# val = co
# Cleaned value is: co
# val = mple
# Cleaned value is: mple
# val = te
#
# Cleaned value is: te
# val = acti
# Cleaned value is: acti
# val = veco
# Cleaned value is: veco
# val = mlet
# Cleaned value is: mlet
# val = e
# Cleaned value is: e
# val =
#
# Cleaned value is:
# val = act
# Cleaned value is: act
# val = ivec
# Cleaned value is: ivec
# val = ompl
# Cleaned value is: ompl
# val = te
#
# Cleaned value is: te
# val = act
# Cleaned value is: act
# val = ivec
# Cleaned value is: ivec
# val = ompl
# Cleaned value is: ompl
# val = ete
# Cleaned value is: ete
# val = ativ
# Cleaned value is: ativ
# val = ec
# Cleaned value is: ec
# val = ompl
# Cleaned value is: ompl
# val = ete
# Cleaned value is: ete
# val =
#
# Cleaned value is:
# val = act
# Cleaned value is: act
# val = ivco
# Cleaned value is: ivco
# val = mp
# Cleaned value is: mp
# val = lete
# Cleaned value is: lete
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = tive
# Cleaned value is: tive
# val = cmpl
# Cleaned value is: cmpl
# val = ete
# Cleaned value is: ete
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = tive
# Cleaned value is: tive
# val = comp
# Cleaned value is: comp
# val = lte
# Cleaned value is: lte
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = tive
# Cleaned value is: tive
# val = comp
# Cleaned value is: comp
# val = lete
# Cleaned value is: lete
# act
# Cleaned value is: act
# val = ive
# Cleaned value is: ive
# val = com
# Cleaned value is: com
# val = plet
# Cleaned value is: plet
# val = e
#
# Cleaned value is: e
# val = a
# Cleaned value is: a
# val = tive
# Cleaned value is: tive
# val = com
# Cleaned value is: com
# val = plet
# Cleaned value is: plet
# val = e
#
# Cleaned value is: e
# val = a
# Cleaned value is: a
# val = ctiv
# Cleaned value is: ctiv
# val = coml
# Cleaned value is: coml
# val = e
#
# Cleaned value is: e
# val = a
# Cleaned value is: a
# val = ctiv
# Cleaned value is: ctiv
# val = ecom
# Cleaned value is: ecom
# val = plet
# Cleaned value is: plet
# val = e
#
# Cleaned value is: e
# val = cti
# Cleaned value is: cti
# val = veco
# Cleaned value is: veco
# val = mple
# Cleaned value is: mple
# val = te
#
# Cleaned value is: te
# val = ctie
# Cleaned value is: ctie
# val = mple
# Cleaned value is: mple
# val = te
#
# Cleaned value is: te
# val = acti
# Cleaned value is: acti
# val = veco
# Cleaned value is: veco
# val = mlet
# Cleaned value is: mlet
# val = e
#
# Cleaned value is: e
# val = acti
# Cleaned value is: acti
# val = veco
# Cleaned value is: veco
# val = mple
# Cleaned value is: mple
# val = e
#
# Cleaned value is: e
# val = act
# Cleaned value is: act
# val = ivec
# Cleaned value is: ivec
# val = ompl
# Cleaned value is: ompl
# val = ete
# Cleaned value is: ete
# val =
#
# Cleaned value is:
# val = act
# Cleaned value is: act
# val = ivco
# Cleaned value is: ivco
# val = mpl
# Cleaned value is: mpl
# val = ete
# Cleaned value is: ete
# val =
# Cleaned value is:
# val = act
# Cleaned value is: act
# val = ivec
# Cleaned value is: ivec
# val = ompl
# Cleaned value is: ompl
# val = t
#
# Cleaned value is: t
# val = act
# Cleaned value is: act
# val = ivec
# Cleaned value is: ivec
# val = ompl
# Cleaned value is: ompl
# val = ete
# Cleaned value is: ete
# val =
#
# Cleaned value is:
# val = tive
# Cleaned value is: tive
# val = comp
# Cleaned value is: comp
# val = lete
# Cleaned value is: lete
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = ivco
# Cleaned value is: ivco
# val = mp
# Cleaned value is: mp
# val = lete
# Cleaned value is: lete
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = tive
# Cleaned value is: tive
# val = ople
# Cleaned value is: ople
# val = te
# Cleaned value is: te
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = tive
# Cleaned value is: tive
# val = comp
# Cleaned value is: comp
# val = lee
# Cleaned value is: lee
# val =
#
# Cleaned value is:
# val = a
# Cleaned value is: a
# val = ctiv
# Cleaned value is: ctiv
# val = ecom
# Cleaned value is: ecom
# val = plet
# Cleaned value is: plet
# val =
#
# Cleaned value is:
# val = ctiv
# Cleaned value is: ctiv
# val = ecom
# Cleaned value is: ecom
# val = plet
# Cleaned value is: plet
# val = e
#
# Cleaned value is: e
# val = a
# Cleaned value is: a
# val = tivc
# Cleaned value is: tivc
# val = plet
# Cleaned value is: plet
# val = e
#
# Cleaned value is: e
# val = a
# Cleaned value is: a
# val = ctiv
# Cleaned value is: ctiv
# val = ecom
# Cleaned value is: ecom
# val = ple
# Cleaned value is: ple
# val = e
# Cleaned value is: e
# val = tve
# Cleaned value is: tve
# val = co
# Cleaned value is: co
# val = mple
# Cleaned value is: mple
# val = te
#
# Cleaned value is: te
# val = acti
# Cleaned value is: acti
# val = ecom
# Cleaned value is: ecom
# val = ple
# Cleaned value is: ple
# val = te
#
# Cleaned value is: te
# val = acti
# Cleaned value is: acti
# val = veco
# Cleaned value is: veco
# val = mple
# Cleaned value is: mple
# val = e
#
# Cleaned value is: e
# val = acti
# Cleaned value is: acti
# val = vec
# Cleaned value is: vec
# val = ompl
# Cleaned value is: ompl
# val = ete
# Cleaned value is: ete
# val = acti
# Cleaned value is: acti
# val = vec
# Cleaned value is: vec
# val = ompl
# Cleaned value is: ompl
# val = ete
# Cleaned value is: ete
# val =
#
# Cleaned value is:
# val = act
# Cleaned value is: act
# val = veom
# Cleaned value is: veom
# val = pl
# Cleaned value is: pl
# val = ete
# Cleaned value is: ete
# val =
#
# Cleaned value is:
# val = act
# Cleaned value is: act
# val = ivec
# Cleaned value is: ivec
# val = mplt
# Cleaned value is: mplt
# val =
#
# Cleaned value is:
# val = act
# Cleaned value is: act
# val = ive
# Cleaned value is: ive
# val = comp
# Cleaned value is: comp
# val = lete
# Cleaned value is: lete
# val =
#
# Cleaned value is:
# val = tive
# Cleaned value is: tive
# val = comp
# Cleaned value is: comp
# val = lete
# Cleaned value is: lete
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = comp
# Cleaned value is: comp
# val = lete
# Cleaned value is: lete
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = tive
# Cleaned value is: tive
# val = omle
# Cleaned value is: omle
# val = te
# Cleaned value is: te
# val =
#
# Cleaned value is:
# val = a
# Cleaned value is: a
# val = ctiv
# Cleaned value is: ctiv
# val = ecom
# Cleaned value is: ecom
# val = plte
# Cleaned value is: plte
# val =
#
# Cleaned value is:
# val = a
# Cleaned value is: a
# val = ctiv
# Cleaned value is: ctiv
# val = ecom
# Cleaned value is: ecom
# val = plet
# Cleaned value is: plet
# val =
#
# Cleaned value is:
# val = ctiv
# Cleaned value is: ctiv
# val = ecom
# Cleaned value is: ecom
# val = plet
# Cleaned value is: plet
# val = e
#
# Cleaned value is: e
# val = a
# Cleaned value is: a
# val = tive
# Cleaned value is: tive
# val = com
# Cleaned value is: com
# val = plet
# Cleaned value is: plet
# val = e
#
# Cleaned value is: e
# val = acti
# Cleaned value is: acti
# val = veom
# Cleaned value is: veom
# val = ple
# Cleaned value is: ple
# val = te
# Cleaned value is: te
# val = acti
# Cleaned value is: acti
# val = veco
# Cleaned value is: veco
# val = mpet
# Cleaned value is: mpet
# val = e
#
# Cleaned value is: e
# val = acti
# Cleaned value is: acti
# val = veco
# Cleaned value is: veco
# val = mple
# Cleaned value is: mple
# val = t
#
# Cleaned value is: t
# val = acti
# Cleaned value is: acti
# val = veco
# Cleaned value is: veco
# val = mpl
# Cleaned value is: mpl
# val = ete
# Cleaned value is: ete
# val = aciv
# Cleaned value is: aciv
# val = ec
# Cleaned value is: ec
# val = ompl
# Cleaned value is: ompl
# val = ete
# Cleaned value is: ete
# val =
#
# Cleaned value is:
# val = act
# Cleaned value is: act
# val = veom
# Cleaned value is: veom
# val = pl
# Cleaned value is: pl
# val = ete
# Cleaned value is: ete
# val =
#
# Cleaned value is:
# val = act
# Cleaned value is: act
# val = ivec
# Cleaned value is: ivec
# val = ople
# Cleaned value is: ople
# val = te
# Cleaned value is: te
# val =
#
# Cleaned value is:
# val = act
# Cleaned value is: act
# val = ivec
# Cleaned value is: ivec
# val = omp
# Cleaned value is: omp
# val = ete
#
# Cleaned value is: ete
# val = tive
# Cleaned value is: tive
# val = comp
# Cleaned value is: comp
# val = lete
# Cleaned value is: lete
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = tvec
# Cleaned value is: tvec
# val = omp
# Cleaned value is: omp
# val = lete
# Cleaned value is: lete
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = tive
# Cleaned value is: tive
# val = ompl
# Cleaned value is: ompl
# val = ete
# Cleaned value is: ete
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = tiv
# Cleaned value is: tiv
# val = ecom
# Cleaned value is: ecom
# val =
# Cleaned value is:
# val = e
#
# Cleaned value is: e
# val = a
# Cleaned value is: a
# val = ctiv
# Cleaned value is: ctiv
# val = ecom
# Cleaned value is: ecom
# val = plet
# Cleaned value is: plet
# ac
# Cleaned value is: eac
# val = tiv
# Cleaned value is: tiv
# val = ecom
# Cleaned value is: ecom
# val = plet
# Cleaned value is: plet
# val = e
# Cleaned value is: e
# val = a
# Cleaned value is: a
# val = tivc
# Cleaned value is: tivc
# val = plet
# Cleaned value is: plet
# val = e
#
# Cleaned value is: e
# val = a
# Cleaned value is: a
# val = cti
# Cleaned value is: cti
# val = veco
# Cleaned value is: veco
# val = te
#
# Cleaned value is: te
# val = acti
# Cleaned value is: acti
# val = veco
# Cleaned value is: veco
# val = mple
# Cleaned value is: mple
# val = t
#
# Cleaned value is: t
# val = acti
# Cleaned value is: acti
# val = veco
# Cleaned value is: veco
# val = mple
# Cleaned value is: mple
# val = te
#
# Cleaned value is: te
# val = atve
# Cleaned value is: atve
# val = co
# Cleaned value is: co
# val = mple
# Cleaned value is: mple
# val = te
# Cleaned value is: te
# val =
#
# Cleaned value is:
# val = act
# Cleaned value is: act
# val = ieom
# Cleaned value is: ieom
# val = pl
# Cleaned value is: pl
# val = ete
# Cleaned value is: ete
# val =
#
# Cleaned value is:
# val = act
# Cleaned value is: act
# val = ivec
# Cleaned value is: ivec
# val = ople
# Cleaned value is: ople
# val = te
# Cleaned value is: te
# val =
#
# Cleaned value is:
# val = act
# Cleaned value is: act
# val = ivec
# Cleaned value is: ivec
# val = ompl
# Cleaned value is: ompl
# val = et
#
# Cleaned value is: et
# val = act
# Cleaned value is: act
# val = ivec
# Cleaned value is: ivec
# val = ompl
# Cleaned value is: ompl
# val = ete
# Cleaned value is: ete
# val =
#
# Cleaned value is:
# val = tive
# Cleaned value is: tive
# val = comp
# Cleaned value is: comp
# val = lete
# Cleaned value is: lete
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = ivco
# Cleaned value is: ivco
# val = mp
# Cleaned value is: mp
# val = lete
# Cleaned value is: lete
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = tive
# Cleaned value is: tive
# val = cmpl
# Cleaned value is: cmpl
# val = ete
# Cleaned value is: ete
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = tive
# Cleaned value is: tive
# val = com
# Cleaned value is: com
# val = pet
# Cleaned value is: pet
# val = ctiv
# Cleaned value is: ctiv
# val = ecom
# Cleaned value is: ecom
# val = plet
# Cleaned value is: plet
# val = e
#
# Cleaned value is: e
# val = a
# Cleaned value is: a
# val = tive
# Cleaned value is: tive
# val = com
# Cleaned value is: com
# val = plet
# Cleaned value is: plet
# val = e
#
# Cleaned value is: e
# val = a
# Cleaned value is: a
# val = ctiv
# Cleaned value is: ctiv
# val = ecmp
# Cleaned value is: ecmp
# val = let
# Cleaned value is: let
# val = e
#
# Cleaned value is: e
# val = a
# Cleaned value is: a
# val = ctiv
# Cleaned value is: ctiv
# val = eco
# Cleaned value is: eco
# val = plet
# Cleaned value is: plet
# val = e
#
# Cleaned value is: e
# val = acti
# Cleaned value is: acti
# val = veco
# Cleaned value is: veco
# val = mple
# Cleaned value is: mple
# val = acti
# Cleaned value is: acti
# val = veco
# Cleaned value is: veco
# val = mple
# Cleaned value is: mple
# val = te
#
# Cleaned value is: te
# val = acti
# Cleaned value is: acti
# val = mple
# Cleaned value is: mple
# val = te
#
# Cleaned value is: te
# val = act
# Cleaned value is: act
# val = ivec
# Cleaned value is: ivec
# val = mplt
# Cleaned value is: mplt
# val =
#
# Cleaned value is:
# val = act
# Cleaned value is: act
# val = ivec
# Cleaned value is: ivec
# val = ompl
# Cleaned value is: ompl
# val = ete
# Cleaned value is: ete
# val = aciv
# Cleaned value is: aciv
# val = ec
# Cleaned value is: ec
# val = ompl
# Cleaned value is: ompl
# val = ete
# Cleaned value is: ete
# val =
#
# Cleaned value is:
# val = act
# Cleaned value is: act
# val = vcom
# Cleaned value is: vcom
# val = pl
# Cleaned value is: pl
# val = ete
# Cleaned value is: ete
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = tive
# Cleaned value is: tive
# val = lete
# Cleaned value is: lete
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = tive
# Cleaned value is: tive
# val = comp
# Cleaned value is: comp
# val = lee
# Cleaned value is: lee
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = tive
# Cleaned value is: tive
# val = comp
# Cleaned value is: comp
# val = lete
# Cleaned value is: lete
# act
# Cleaned value is: act
# val = ive
# Cleaned value is: ive
# val = comp
# Cleaned value is: comp
# val = let
# Cleaned value is: let
# val = e
#
# Cleaned value is: e
# val = a
# Cleaned value is: a
# val = ctiv
# Cleaned value is: ctiv
# val = eomp
# Cleaned value is: eomp
# val = let
# Cleaned value is: let
# val = e
#
# Cleaned value is: e
# val = a
# Cleaned value is: a
# val = ctiv
# Cleaned value is: ctiv
# val = ecom
# Cleaned value is: ecom
# val = pete
# Cleaned value is: pete
# val =
#
# Cleaned value is:
# val = a
# Cleaned value is: a
# val = ctiv
# Cleaned value is: ctiv
# val = ecom
# Cleaned value is: ecom
# val = plet
# Cleaned value is: plet
# val =
#
# Cleaned value is:
# val = ctiv
# Cleaned value is: ctiv
# val = ecom
# Cleaned value is: ecom
# val = ple
# Cleaned value is: ple
# val = te
#
# Cleaned value is: te
# val = aciv
# Cleaned value is: aciv
# val = eco
# Cleaned value is: eco
# val = mple
# Cleaned value is: mple
# val = te
#
# Cleaned value is: te
# val = acti
# Cleaned value is: acti
# val = mple
# Cleaned value is: mple
# val = te
#
# Cleaned value is: te
# val = acti
# Cleaned value is: acti
# val = veco
# Cleaned value is: veco
# val = mlee
# Cleaned value is: mlee
# val = acti
# Cleaned value is: acti
# val = vec
# Cleaned value is: vec
# val = ompl
# Cleaned value is: ompl
# val = ete
# Cleaned value is: ete
# val = acti
# Cleaned value is: acti
# val = vec
# Cleaned value is: vec
# val = ompl
# Cleaned value is: ompl
# val = ete
# Cleaned value is: ete
# val =
#
# Cleaned value is:
# val = act
# Cleaned value is: act
# val = veco
# Cleaned value is: veco
# val = mpl
# Cleaned value is: mpl
# val = ete
# Cleaned value is: ete
# val =
#
# Cleaned value is:
# val = act
# Cleaned value is: act
# val = ivec
# Cleaned value is: ivec
# val = ete
# Cleaned value is: ete
# val =
#
# Cleaned value is:
# val = act
# Cleaned value is: act
# val = ive
# Cleaned value is: ive
# val = comp
# Cleaned value is: comp
# val = lee
# Cleaned value is: lee
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = tive
# Cleaned value is: tive
# val = comp
# Cleaned value is: comp
# val = lete
# Cleaned value is: lete
# val =
#
# Cleaned value is:
# val = tive
# Cleaned value is: tive
# val = comp
# Cleaned value is: comp
# val = lete
# Cleaned value is: lete
# val =
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = ivec
# Cleaned value is: ivec
# val = omp
# Cleaned value is: omp
# val = lete
# Cleaned value is: lete
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = tiv
# Cleaned value is: tiv
# val = ecom
# Cleaned value is: ecom
# val = pete
# Cleaned value is: pete
# val =
#
# Cleaned value is:
# val = a
# Cleaned value is: a
# val = ctiv
# Cleaned value is: ctiv
# val = ecom
# Cleaned value is: ecom
# val = plet
# Cleaned value is: plet
# val =
#
# Cleaned value is:
# val = ctiv
# Cleaned value is: ctiv
# val = ecom
# Cleaned value is: ecom
# val = plet
# Cleaned value is: plet
# val = e
#
# Cleaned value is: e
# val = a
# Cleaned value is: a
# val = tivc
# Cleaned value is: tivc
# val = plet
# Cleaned value is: plet
# val = e
#
# Cleaned value is: e
# val = acti
# Cleaned value is: acti
# val = veco
# Cleaned value is: veco
# val = mlet
# Cleaned value is: mlet
# val = e
#
# Cleaned value is: e
# val = acti
# Cleaned value is: acti
# val = veco
# Cleaned value is: veco
# val = mple
# Cleaned value is: mple
# val = te
#
# Cleaned value is: te
# val = veco
# Cleaned value is: veco
# val = mple
# Cleaned value is: mple
# val = te
#
# Cleaned value is: te
# val = acti
# Cleaned value is: acti
# val = empl
# Cleaned value is: empl
# val = e
# Cleaned value is: e
# val = te
# Cleaned value is: te
# val =
#
# Cleaned value is:
# val = act
# Cleaned value is: act
# val = ivec
# Cleaned value is: ivec
# val = ete
# Cleaned value is: ete
# val =
#
# Cleaned value is:
# val = act
# Cleaned value is: act
# val = ivec
# Cleaned value is: ivec
# val = ompl
# Cleaned value is: ompl
# val = et
#
# Cleaned value is: et
# val = act
# Cleaned value is: act
# val = ivec
# Cleaned value is: ivec
# val = ompl
# Cleaned value is: ompl
# val = ete
# Cleaned value is: ete
# val = ivec
# Cleaned value is: ivec
# val = omp
# Cleaned value is: omp
# val = lete
# Cleaned value is: lete
# val =
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = tive
# Cleaned value is: tive
# val = ompl
# Cleaned value is: ompl
# val = ete
# Cleaned value is: ete
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = tive
# Cleaned value is: tive
# val = comp
# Cleaned value is: comp
# val = ee
#
# Cleaned value is: ee
# val = ac
# Cleaned value is: ac
# val = tive
# Cleaned value is: tive
# val = comp
# Cleaned value is: comp
# val = lete
# Cleaned value is: lete
# act
# Cleaned value is: act
# val = ive
# Cleaned value is: ive
# val = com
# Cleaned value is: com
# val = plet
# Cleaned value is: plet
# val = e
#
# Cleaned value is: e
# val = a
# Cleaned value is: a
# val = cive
# Cleaned value is: cive
# val = com
# Cleaned value is: com
# val = plet
# Cleaned value is: plet
# val = e
#
# Cleaned value is: e
# val = a
# Cleaned value is: a
# val = ctiv
# Cleaned value is: ctiv
# val = cmpl
# Cleaned value is: cmpl
# val = et
# Cleaned value is: et
# val = e
#
# Cleaned value is: e
# val = a
# Cleaned value is: a
# val = ctiv
# Cleaned value is: ctiv
# val = ecom
# Cleaned value is: ecom
# val = plet
# Cleaned value is: plet
# val = e
#
# Cleaned value is: e
# val = cti
# Cleaned value is: cti
# val = veco
# Cleaned value is: veco
# val = mple
# Cleaned value is: mple
# val = te
#
# Cleaned value is: te
# val = veco
# Cleaned value is: veco
# val = mple
# Cleaned value is: mple
# val = te
#
# Cleaned value is: te
# val = acti
# Cleaned value is: acti
# val = veco
# Cleaned value is: veco
# val = mlet
# Cleaned value is: mlet
# val = e
#
# Cleaned value is: e
# val = acti
# Cleaned value is: acti
# val = veco
# Cleaned value is: veco
# val = mple
# Cleaned value is: mple
# val = te
#
# Cleaned value is: te
# val = ati
# Cleaned value is: ati
# val = vec
# Cleaned value is: vec
# val = ompl
# Cleaned value is: ompl
# val = ete
# Cleaned value is: ete
# val =
#
# Cleaned value is:
# val = act
# Cleaned value is: act
# val = ivec
# Cleaned value is: ivec
# val = mple
# Cleaned value is: mple
# val = te
# Cleaned value is: te
# val =
# Cleaned value is:
# val = act
# Cleaned value is: act
# val = ivec
# Cleaned value is: ivec
# val = ompl
# Cleaned value is: ompl
# val = ete
# Cleaned value is: ete
# val =
#
# Cleaned value is:
# val = ivec
# Cleaned value is: ivec
# val = ompl
# Cleaned value is: ompl
# val = ete
# Cleaned value is: ete
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = ieco
# Cleaned value is: ieco
# val = mp
# Cleaned value is: mp
# val = lete
# Cleaned value is: lete
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = tive
# Cleaned value is: tive
# val = omle
# Cleaned value is: omle
# val = te
# Cleaned value is: te
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = tive
# Cleaned value is: tive
# val = comp
# Cleaned value is: comp
# val = lte
# Cleaned value is: lte
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = tive
# Cleaned value is: tive
# val = comp
# Cleaned value is: comp
# val = let
# Cleaned value is: let
# ac
# Cleaned value is: eac
# val = tiv
# Cleaned value is: tiv
# val = ecom
# Cleaned value is: ecom
# val = plet
# Cleaned value is: plet
# val = e
#
# Cleaned value is: e
# val = a
# Cleaned value is: a
# val = ecom
# Cleaned value is: ecom
# val = plet
# Cleaned value is: plet
# val = e
#
# Cleaned value is: e
# val = a
# Cleaned value is: a
# val = ctiv
# Cleaned value is: ctiv
# val = comp
# Cleaned value is: comp
# val = let
# Cleaned value is: let
# val = e
#
# Cleaned value is: e
# val = a
# Cleaned value is: a
# val = ctiv
# Cleaned value is: ctiv
# val = eco
# Cleaned value is: eco
# val = plet
# Cleaned value is: plet
# val = e
#
# Cleaned value is: e
# val = acti
# Cleaned value is: acti
# val = veco
# Cleaned value is: veco
# val = mple
# Cleaned value is: mple
# val = t
#
# Cleaned value is: t
# val = acti
# Cleaned value is: acti
# val = veco
# Cleaned value is: veco
# val = mple
# Cleaned value is: mple
# val = te
#
# Cleaned value is: te
# val = veco
# Cleaned value is: veco
# val = mple
# Cleaned value is: mple
# val = te
#
# Cleaned value is: te
# val = acti
# Cleaned value is: acti
# val = vec
# Cleaned value is: vec
# val = mple
# Cleaned value is: mple
# val = te
# Cleaned value is: te
# val =
#
# Cleaned value is:
# val = act
# Cleaned value is: act
# val = ivec
# Cleaned value is: ivec
# val = ompl
# Cleaned value is: ompl
# val =
# Cleaned value is:
# val =
#
# Cleaned value is:
# val = act
# Cleaned value is: act
# val = ivec
# Cleaned value is: ivec
# val = ompl
# Cleaned value is: ompl
# val = ete
# Cleaned value is: ete
# val =
#
# Cleaned value is:
# val = ivec
# Cleaned value is: ivec
# val = ompl
# Cleaned value is: ompl
# val = ete
# Cleaned value is: ete
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = ivco
# Cleaned value is: ivco
# val = mp
# Cleaned value is: mp
# val = lete
# Cleaned value is: lete
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = tive
# Cleaned value is: tive
# val = lete
# Cleaned value is: lete
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = tive
# Cleaned value is: tive
# val = comp
# Cleaned value is: comp
# val = ete
# Cleaned value is: ete
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = tive
# Cleaned value is: tive
# val = comp
# Cleaned value is: comp
# val = lete
# Cleaned value is: lete
# ac
# Cleaned value is: ac
# val = tiv
# Cleaned value is: tiv
# val = ecom
# Cleaned value is: ecom
# val = plet
# Cleaned value is: plet
# val = e
#
# Cleaned value is: e
# val = a
# Cleaned value is: a
# val = iec
# Cleaned value is: iec
# val = om
# Cleaned value is: om
# val = plet
# Cleaned value is: plet
# val = e
#
# Cleaned value is: e
# val = a
# Cleaned value is: a
# val = ctiv
# Cleaned value is: ctiv
# val = ecom
# Cleaned value is: ecom
# val = te
# Cleaned value is: te
# val =
#
# Cleaned value is:
# val = a
# Cleaned value is: a
# val = ctiv
# Cleaned value is: ctiv
# val = ecom
# Cleaned value is: ecom
# val = ple
# Cleaned value is: ple
# ac
# Cleaned value is: eac
# val = ti
# Cleaned value is: ti
# val = veco
# Cleaned value is: veco
# val = mple
# Cleaned value is: mple
# val = te
# Cleaned value is: te
# val = actv
# Cleaned value is: actv
# val = eco
# Cleaned value is: eco
# val = mple
# Cleaned value is: mple
# val = te
#
# Cleaned value is: te
# val = acti
# Cleaned value is: acti
# val = eomp
# Cleaned value is: eomp
# val = le
# Cleaned value is: le
# val = te
#
# Cleaned value is: te
# val = acti
# Cleaned value is: acti
# val = veco
# Cleaned value is: veco
# val = ple
# Cleaned value is: ple
# val = te
# Cleaned value is: te
# val =
# Cleaned value is:
# val = act
# Cleaned value is: act
# val = ivec
# Cleaned value is: ivec
# val = ompl
# Cleaned value is: ompl
# val = ete
# Cleaned value is: ete
# val =
#
# Cleaned value is:
# val = ivec
# Cleaned value is: ivec
# val = ompl
# Cleaned value is: ompl
# val = ete
# Cleaned value is: ete
# val =
#
# Cleaned value is:
# val = act
# Cleaned value is: act
# val = veco
# Cleaned value is: veco
# val = mpl
# Cleaned value is: mpl
# val = ete
# Cleaned value is: ete
# val =
#
# Cleaned value is:
# val = act
# Cleaned value is: act
# val = ive
# Cleaned value is: ive
# val = lete
# Cleaned value is: lete
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = tive
# Cleaned value is: tive
# val = comp
# Cleaned value is: comp
# val = lete
# Cleaned value is: lete
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = tive
# Cleaned value is: tive
# val = comp
# Cleaned value is: comp
# val = lete
# Cleaned value is: lete
# val =
#
# Cleaned value is:
# val = c
# Cleaned value is: c
# val = tive
# Cleaned value is: tive
# val = comp
# Cleaned value is: comp
# val = lete
# Cleaned value is: lete
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = tve
# Cleaned value is: tve
# val = com
# Cleaned value is: com
# val = plet
# Cleaned value is: plet
# val = e
#
# Cleaned value is: e
# val = a
# Cleaned value is: a
# val = ctiv
# Cleaned value is: ctiv
# val = ecom
# Cleaned value is: ecom
# val = pete
# Cleaned value is: pete
# val =
#
# Cleaned value is:
# val = a
# Cleaned value is: a
# val = ctiv
# Cleaned value is: ctiv
# val = ecom
# Cleaned value is: ecom
# val = plet
# Cleaned value is: plet
# val =
#
# Cleaned value is:
# val = ctiv
# Cleaned value is: ctiv
# val = ecom
# Cleaned value is: ecom
# val = plet
# Cleaned value is: plet
# val = e
#
# Cleaned value is: e
# val = ativ
# Cleaned value is: ativ
# val = eco
# Cleaned value is: eco
# val = mple
# Cleaned value is: mple
# val = te
#
# Cleaned value is: te
# val = acti
# Cleaned value is: acti
# val = ecop
# Cleaned value is: ecop
# val = te
# Cleaned value is: te
# val = acti
# Cleaned value is: acti
# val = veco
# Cleaned value is: veco
# val = mple
# Cleaned value is: mple
# val = t
#
# Cleaned value is: t
# val = acti
# Cleaned value is: acti
# val = veco
# Cleaned value is: veco
# val = mple
# Cleaned value is: mple
# val = te
# Cleaned value is: te
# val =
#
# Cleaned value is:
# val = act
# Cleaned value is: act
# val = ieco
# Cleaned value is: ieco
# val = mpl
# Cleaned value is: mpl
# val = ete
# Cleaned value is: ete
# val =
# Cleaned value is:
# val = act
# Cleaned value is: act
# val = ivec
# Cleaned value is: ivec
# val = mlt
# Cleaned value is: mlt
# val =
#
# Cleaned value is:
# val = act
# Cleaned value is: act
# val = ivec
# Cleaned value is: ivec
# val = ompl
# Cleaned value is: ompl
# val = ete
# Cleaned value is: ete
# val =
#
# Cleaned value is:
# val = act
# Cleaned value is: act
# val = veco
# Cleaned value is: veco
# val = mp
# Cleaned value is: mp
# val = lete
# Cleaned value is: lete
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = tive
# Cleaned value is: tive
# val = lete
# Cleaned value is: lete
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = tive
# Cleaned value is: tive
# val = comp
# Cleaned value is: comp
# val = ee
#
# Cleaned value is: ee
# val = tive
# Cleaned value is: tive
# val = comp
# Cleaned value is: comp
# val = lete
# Cleaned value is: lete
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = c
# Cleaned value is: c
# val = om
# Cleaned value is: om
# val = plet
# Cleaned value is: plet
# val = e
#
# Cleaned value is: e
# val = a
# Cleaned value is: a
# val = ctiv
# Cleaned value is: ctiv
# val = comp
# Cleaned value is: comp
# val = let
# Cleaned value is: let
# val = e
#
# Cleaned value is: e
# val = a
# Cleaned value is: a
# val = ctiv
# Cleaned value is: ctiv
# val = ecom
# Cleaned value is: ecom
# val = e
# Cleaned value is: e
# val =
#
# Cleaned value is:
# val = a
# Cleaned value is: a
# val = ctiv
# Cleaned value is: ctiv
# val = ecom
# Cleaned value is: ecom
# val = plet
# Cleaned value is: plet
# val = e
#
# Cleaned value is: e
# val = ctiv
# Cleaned value is: ctiv
# val = eco
# Cleaned value is: eco
# val = mple
# Cleaned value is: mple
# val = te
#
# Cleaned value is: te
# val = veco
# Cleaned value is: veco
# val = mple
# Cleaned value is: mple
# val = te
#
# Cleaned value is: te
# val = acti
# Cleaned value is: acti
# val = ecom
# Cleaned value is: ecom
# val = ple
# Cleaned value is: ple
# val = te
# Cleaned value is: te
# val = acti
# Cleaned value is: acti
# val = veco
# Cleaned value is: veco
# val = te
#
# Cleaned value is: te
# val = act
# Cleaned value is: act
# val = ivec
# Cleaned value is: ivec
# val = ompl
# Cleaned value is: ompl
# val = et
#
# Cleaned value is: et
# val = act
# Cleaned value is: act
# val = ivec
# Cleaned value is: ivec
# val = ompl
# Cleaned value is: ompl
# val = ete
# Cleaned value is: ete
# val =
# Cleaned value is:
# val = ivec
# Cleaned value is: ivec
# val = ompl
# Cleaned value is: ompl
# val = ete
# Cleaned value is: ete
# val =
#
# Cleaned value is:
# val = act
# Cleaned value is: act
# val = ieco
# Cleaned value is: ieco
# val = mpl
# Cleaned value is: mpl
# val = ete
# Cleaned value is: ete
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = tive
# Cleaned value is: tive
# val = lete
# Cleaned value is: lete
# val =
#
# Cleaned value is:
# val = ac
# Cleaned value is: ac
# val = tive
# Cleaned value is: tive
# val = comp
# Cleaned value is: comp
# val = t
#
# Cleaned value is: t
# val = ac
# Cleaned value is: ac
# val = tive
# Cleaned value is: tive
# val = comp
# Cleaned value is: comp
# val = lete
# Cleaned value is: lete
# val =
#
# Cleaned value is:
# val = tive
# Cleaned value is: tive
# val = comp
# Cleaned value is: comp
# val = let
# Cleaned value is: let
# val = e
#
# Cleaned value is: e
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-81d996fae0c9> in <module>()
#       8     full_val = ''
#       9     #Pull the line
# ---> 10     if arduino.inWaiting():
#      11         try:
#      12             val = arduino.readline(arduino.inWaiting())
#
# /Users/dan/anaconda/lib/python2.7/site-packages/serial/serialposix.pyc in inWaiting(self)
#     447         """Return the number of characters currently in the input buffer."""
#     448         #~ s = fcntl.ioctl(self.fd, TERMIOS.FIONREAD, TIOCM_zero_str)
# --> 449         s = fcntl.ioctl(self.fd, TIOCINQ, TIOCM_zero_str)
#     450         return struct.unpack('I',s)[0]
#     451
#
# KeyboardInterrupt:

# %%
# open arduino stream
val = 0
full_val = ''
#From  http://www.olgapanades.com/blog/controlling-arduino-with-python/
arduino = serial.Serial('/dev/tty.usbmodemfa141', 9600)
print "listening on serial"

while 1:
    #Reset variables
    val = 0
    full_val = ''
    #Pull the line
    try:
        val = arduino.readline()

        for char in val:
            #Make sure that the character isn't some weird thing
            if char.isalpha():
                full_val = full_val + char
        print "Cleaned value is: " + full_val
        if full_val == 'activecomplete':
            print 'received activecomplete, now listening...'
            checkaudio(1, ambientLevel)
            break
        elif full_val == 'quietcomplete':
            print 'received quietcomplete, now listening...'
            checkaudio(2, ambientLevel)
            break
    except serial.serialutil.SerialException:
        pass
# Out:
# listening on serial
# Cleaned value is: ativecomplete
# Cleaned value is: actvomplete
# Cleaned value is: activecmplete
# Cleaned value is: activecomplee
# Cleaned value is: activecomplete
# received activecomplete, now listening...
# 580
# 560
# 530
# 624
# 1035
# 750
# 801
# 716
# 594
# 447
# 431
# 407
# 1125
# 1264
# 1094
# 778
# 847
# 874
# 967
# 746
# 1127
# 754
# 476
# 387
# 322
# 470
# 416
# 427
# 456
# 602
# 1236
# 623
# 905
# 920
# 1156
# 862
# 761
# 622
# 663
# 814
# 686
# 610
# 916
# 1225
# 1363
# 1890
# 2599
# 1491
# 892
# 1092
# 907
# 1018
# 1237
# 1004
# 1055
# 937
# 376
# 419
# 655
# 758
# 1023
# 865
# 540
# 253
# 209
# 228
# 591
# 460
# 403
# 397
# 361
# 345
# 234
# 230
# 364
# 338
# 446
# 530
# 545
# 477
# 882
# 816
# 782
# 915
# 694
# 505
# 442
# 408
# 398
# 367
# 645
# 1206
# 1831
# 1471
# 795
# 663
# 1153
# 915
# 847
# 588
# 492
# 394
# 260
# 393
# 445
# 445
# 376
# 359
# 300
# 269
# 310
# 350
# 369
# 406
# 590
# 643
# 691
# 425
# 760
# 1091
# 844
# 890
# 702
# 330
# 452
# 456
# 541
# 1310
# 1971
# 1032
# 820
# 724
# 515
# 406
# 290
# 316
# 1025
# 2028
# 1522
# 2034
# 2190
# 2000
# 1918
# 1394
# 2155
# 656
# 437
# 452
# 1230
# 657
# 1006
# 1169
# 980
# 588
# 344
# 255
# 210
# 205
# 214
# 215
# 235
# 243
# 246
# 566
# 448
# 407
# 440
# 516
# 373
# 369
# 301
# 359
# 489
# 1033
# 627
# 977
# 824
# 915
# 812
# 758
# 892
# 1024
# 1441
# 1168
# 1238
# 1062
# 587
# 458
# 386
# 772
# 830
# 652
# 293
# 228
# 253
# 321
# 421
# 543
# 702
# 530
# 441
# 487
# 575
# 370
# 370
# 411
# 816
# 721
# 631
# 499
# 476
# 929
# 1231
# 1593
# 1776
# 595
# 1083
# 624
# 868
# 871
# 745
# 493
# 1043
# 2021
# 2349
# 2592
# 2363
# 2674
# 1913
# 1109
# 921
# 1063
# 798
# 1353
# 1105
# 622
# 1141
# 1092
# 632
# 648
# 1251
# 1457
# 2102
# 2057
# 1663
# 1352
# 1059
# 561
# 303
# 438
# 444
# 644
# 540
# 462
# 393
# 273
# 269
# 383
# 560
# 366
# 228
# 201
# 170
# 349
# 455
# 361
# 594
# 495
# 418
# 429
# 406
# 390
# 2482
# 3899
# 2443
# 2145
# 2040
# 977
# 830
# 725
# 512
# 671
# 1307
# 592
# 411
# 368
# 306
# 925
# 857
# 734
# 409
# 258
# 236
# 203
# 255
# 456
# 320
# 253
# 243
# 266
# 584
# 486
# 380
# 529
# 740
# 549
# 718
# 824
# 387
# 557
# 469
# 390
# 383
# 402
# 455
# 244
# 346
# 367
# 356
# 224
# 296
# 701
# 192
# 245
# 240
# 227
# 211
# 309
# 204
# 258
# 1516
# 1416
# 663
# 429
# 363
# 361
# 411
# 357
# 364
# 577
# 517
# 757
# 1457
# 1386
# 1584
# 1029
# 578
# 413
# 219
# 249
# 182
# 139
# 109
# 108
# 268
# 77
# 78
# 85
# 69
# 66
# 65
# 67
# 57
# 70
# 64
# 46
# 53
# 55
# 80
# 41
# 60
# 56
# 53
# 44
# 44
# 48
# 43
# 62
# 53
# 47
# 41
# 47
# 47
# 37
# 42
# 43
# 73
# 136
# 277
# 318
# 142
# 92
# 86
# 139
# 237
# 87
# 132
# 137
# 105
# 55
# 63
# 78
# 50
# 46
# 61
# 70
# 51
# 41
# 43
# 52
# 41
# 57
# 51
# 36
# 41
# 51
# 42
# 36
# 48
# 40
# 47
# 31
# 45
# 45
# 40
# 42
# 37
# 42
# 38
# 40
